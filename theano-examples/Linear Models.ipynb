# %% [markdown]
# # Fit a linear Model
#
# Lets learn the $w$ of the linear function $\hat{y} = w \cdot x $ based on data points randomly drawn from $y = 2x + \varepsilon $
#
# We use:
# * mean-square-error as the cost function $c = \frac{1}{n} \sum_{n} {\left (  \hat{y} - y \right )}^2 $
# * the build-in [`Tensor.grad` function](http://deeplearning.net/software/theano/library/gradient.html) to get the gradient with respect to $c$
#
# and update $w$ in each iteration to minimize the cost function

# %% [markdown]
# ### Let's fit the function

# %%
import theano
from theano import tensor as T
import numpy as np
import pandas as ps 
import time
from IPython import display

# lets create sample data based on trY = w*trX + error
trw = 20
number_of_samples = 100
error = 0.33
trX = np.linspace(-1, 1, number_of_samples+1)
trY = trw * trX + np.random.randn(*trX.shape) * error


learning_rate = 0.001
number_of_iterations = 20

x = T.scalar('x')
y = T.scalar('y')

def model(x, w):
    return x * w

w = theano.shared(np.asarray(0., dtype=theano.config.floatX))
y_hat = model(x, w)

cost = T.mean(T.sqr(y_hat - y))
gradient = T.grad(cost=cost, wrt=w)
updates = [[w, w - gradient * learning_rate]]

train = theano.function(inputs=[x, y], outputs=cost, updates=updates, allow_input_downcast=True)

error = []
ws=[]
for i in range(number_of_iterations):
    iteration_error = 0
    for x_in, y_in in zip(trX, trY):
        e = train(x_in, y_in)
        iteration_error += e
    iteration_error /= len(trX)
    print iteration_error
    error.append(iteration_error)
    ws.append(w.get_value())
# Out:
# 127.796623466
# 111.404079083
# 97.1165894396
# 84.6638315292
# 73.810196291
# 64.3503307561
# 56.10525266
# 48.9189640031
# 42.6554994878
# 37.1963539855
# 32.4382403601
# 28.2911352245
# 24.6765756556
# 21.5261746383
# 18.7803271527
# 16.3870824203
# 14.3011609738
# 12.4830979501
# 10.8984964005
# 9.51737648665

# %% [markdown]
# ### Plot error

# %%
s = ps.DataFrame({'error': error})
s.plot()
plt.show()

# %% [markdown]
# ### Plot w

# %%
fig, ax = plt.subplots(1)
ax.scatter(x=trX, y=trY)

for i in range(number_of_iterations-1):
    ax.plot(trX, trX*ws[i], ':', color='r')
    plt.title('iteration %d  w=%0.2f error=%0.2f' % ((i+1), ws[i], error[i]))
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(0.5)
i+=1
display.clear_output(wait=True)
ax.plot(trX, trX*ws[i], '-', color='r')
plt.title('iteration %d  w=%0.2f error=%0.2f' % ((i+1), ws[i], error[i]))
plt.show()
